# %%
import psycopg2
import pandas as pd
import json
import pyarrow as pa
import pyarrow.parquet as pq
import os

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
conn = psycopg2.connect(
    host='localhost',
    port=5434,
    user='airflow',
    password='airflow',
    dbname='common_crawl_db',
)

query = """
SELECT *
FROM result_table
"""

df = pd.read_sql_query(query, conn)
df['subsections'] = df['subsections'].apply(lambda x: set(json.loads(x)))
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14012\1828101135.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
df.head()
# Out:
#                       homepage  is_homepage  count  \
# 0                          ://        False      3
# 1          http://0.baivli.com        False      3
# 2           http://0287327.com        False      3
# 3            http://029scy.com        False      3
# 4  http://08l.happymealbox.net        False      3
#
#                                                                                                                                                        subsections  \
# 0  {CC-MAIN-20240712094214-20240712124214-00000.warc.gz, CC-MAIN-20240712094214-20240712124214-00001.warc.gz, CC-MAIN-20240712094214-20240712124214-00002.warc.gz}
# 1                                                                                                                                       {/play/nzn_cr/MYgEBA.html}
# 2                                                                                                                                                  {/1261520.html}
# 3                                                                                                                                             {/bbcef/238899.html}
# 4                                                                                                                    {/new-equipment/attachments/couplers-loader/}
#
#    country          category  is_ad_based
# 0  UNKNOWN      Food & Drink        False
# 1  UNKNOWN    Pets & Animals        False
# 2  UNKNOWN  Autos & Vehicles        False
# 3  UNKNOWN  People & Society        False
# 4  UNKNOWN    Pets & Animals        False

# %%
# 1. Percentage of Categorised Websites
def percentage_websites_categorized(df):
    total_sites = len(df)
    categorized_sites = df[df['category'] != 'UNKNOWN']
    return round((len(categorized_sites) * 100 / total_sites), 2)

# 2. Assess how many uncategorised sites are actually ad-based
def percentage_website_not_categorized_ad_based(df):
    non_categorized_sites = df[df['category'] == 'UNKNOWN']
    non_categorized_ad_based_sites = non_categorized_sites['is_ad_based'].sum()
    return (non_categorized_ad_based_sites / len(non_categorized_sites)) * 100

# 3. Top 5 Categories per count
def top_5_categories(df):
    return df['category'].value_counts().reset_index().head(5)

# 4. Distribution of websites per country - Mode of categories per country
def mode_category_per_country(df):
    return df.groupby('country')['category'].agg(lambda x: x.mode().iloc[0])

# 5. Country with multiple sites/subdomains
def country_with_most_ws_sd(df):
    return df[df['country'] != 'UNKNOWN']['country'].value_counts().idxmax()

# %%
percentage_categorized_df = percentage_websites_categorized(df)
percentage_not_categorized_ad_based_df = percentage_website_not_categorized_ad_based(df)
top_5_categories_df = top_5_categories(df)
mode_per_country_df = mode_category_per_country(df)
country_with_most_ws_sd_df = country_with_most_ws_sd(df)

# %%
print("# 1. Percentage of Categorised Websites:", percentage_categorized_df)
# Out:
# # 1. Percentage of Categorised Websites: 96.38

# %%
print("# 2. Percentage of Uncategorized Sites that are Ad-Based:", percentage_not_categorized_ad_based_df)
# Out:
# # 2. Percentage of Uncategorized Sites that are Ad-Based: 50.26123301985371

# %%
print("Top 5 Categories per count:\n",)
top_5_categories_df
# Out:
# Top 5 Categories per count:
#             category  count
# 0  Hobbies & Leisure   1969
# 1          Reference   1957
# 2       Food & Drink   1933
# 3   Autos & Vehicles   1933
# 4            Science   1927

# %%
print("# 4. Mode of categories per country:\n", mode_per_country_df)
# Out:
# # 4. Mode of categories per country:
#  country
# DE                          Travel
# UNKNOWN                  Reference
# ad               Hobbies & Leisure
# ae                Autos & Vehicles
# af                        Shopping
# ag            Arts & Entertainment
# ai                     Real Estate
# al              Internet & Telecom
# am                Autos & Vehicles
# ao              Internet & Telecom
# ar               Hobbies & Leisure
# as                           Adult
# at            Arts & Entertainment
# au                       Reference
# aw                       Reference
# ax                Jobs & Education
# az               Hobbies & Leisure
# ba                Beauty & Fitness
# bd         Computers & Electronics
# be            Arts & Entertainment
# bf                         Science
# bg                People & Society
# bh                Law & Government
# bi                Law & Government
# bm                          Sports
# bo                         Science
# br           Business & Industrial
# bt                Law & Government
# bw                Beauty & Fitness
# by                           Games
# bz                People & Society
# ca                    Food & Drink
# cc                          Sports
# cd              Books & Literature
# cg                         UNKNOWN
# ch                Autos & Vehicles
# ci                  Pets & Animals
# ck                          Sports
# cl                           Adult
# cn                Autos & Vehicles
# co                         Finance
# cr              Online Communities
# cu              Books & Literature
# cv                   Home & Garden
# cy                    Food & Drink
# cz                         Finance
# de                Autos & Vehicles
# dj                  Pets & Animals
# dk                           Adult
# do           Business & Industrial
# dz                    Food & Drink
# ec                  Pets & Animals
# ee                Autos & Vehicles
# eg                People & Society
# es                           Adult
# et               Hobbies & Leisure
# eu                    Food & Drink
# fi                Beauty & Fitness
# fj                Autos & Vehicles
# fm                          Travel
# fo                    Food & Drink
# fr              Books & Literature
# ga                Beauty & Fitness
# ge              Books & Literature
# gg                           Adult
# gh                           Adult
# gi           Business & Industrial
# gl           Business & Industrial
# gn                          Sports
# gp                           Adult
# gr                Law & Government
# gt                Autos & Vehicles
# gy              Online Communities
# hk                   Home & Garden
# hn                Beauty & Fitness
# hr         Computers & Electronics
# ht            Arts & Entertainment
# hu            Arts & Entertainment
# id                          Sports
# ie                        Shopping
# il                        Shopping
# im           Business & Industrial
# in                         Science
# io              Internet & Telecom
# iq                Beauty & Fitness
# ir                         Finance
# is                            News
# it                Law & Government
# je            Arts & Entertainment
# jo                          Health
# jp         Computers & Electronics
# ke         Computers & Electronics
# kg                Beauty & Fitness
# kh              Books & Literature
# ki                          Health
# kr              Books & Literature
# kw           Business & Industrial
# ky                     Real Estate
# kz                         Science
# la         Computers & Electronics
# lb                  Pets & Animals
# lc                            News
# li                          Health
# lk         Computers & Electronics
# ls            Arts & Entertainment
# lt            Arts & Entertainment
# lu                         Science
# lv                Jobs & Education
# ly              Online Communities
# ma              Books & Literature
# md                           Adult
# me                   Home & Garden
# mk                         UNKNOWN
# mm                        Shopping
# mn                           Adult
# mo                Law & Government
# mr               Hobbies & Leisure
# ms                   Home & Garden
# mt            Arts & Entertainment
# mu                           Adult
# mv                Jobs & Education
# mw                            News
# mx                           Adult
# my                    Food & Drink
# mz                         Finance
# na         Computers & Electronics
# nc                People & Society
# ne                            News
# nf                         Finance
# ng                           Adult
# ni                           Adult
# nl                Autos & Vehicles
# no         Computers & Electronics
# np                Law & Government
# nr                   Home & Garden
# nu                         Science
# nz                Autos & Vehicles
# pa                Beauty & Fitness
# pe              Online Communities
# ph                          Sports
# pk                          Health
# pl                Law & Government
# pn                Autos & Vehicles
# pr              Internet & Telecom
# ps                          Health
# pt                Autos & Vehicles
# pw         Computers & Electronics
# py                Beauty & Fitness
# qa           Business & Industrial
# re                           Games
# ro                   Home & Garden
# rs                Law & Government
# ru                Law & Government
# rw              Books & Literature
# sa                Autos & Vehicles
# sb                  Pets & Animals
# sc                          Travel
# se                         Science
# sg                           Adult
# sh                       Reference
# si                       Reference
# sk              Books & Literature
# sm                        Shopping
# sn                Beauty & Fitness
# so                           Adult
# sr                   Home & Garden
# st                           Adult
# su              Books & Literature
# sv                          Health
# sy              Books & Literature
# sz                         Science
# tc           Business & Industrial
# td           Business & Industrial
# tg                   Home & Garden
# th                Beauty & Fitness
# tj                         UNKNOWN
# tk                Jobs & Education
# tl                Autos & Vehicles
# tm                          Travel
# tn            Arts & Entertainment
# to                Beauty & Fitness
# tr              Internet & Telecom
# tt            Arts & Entertainment
# tv                  Pets & Animals
# tw                            News
# tz                           Adult
# ua                          Sports
# ug                           Games
# uk                     Real Estate
# us              Online Communities
# uy                         Finance
# uz                  Pets & Animals
# va                         Finance
# vc                            News
# ve            Arts & Entertainment
# vi                           Adult
# vn            Arts & Entertainment
# wf                         UNKNOWN
# ws                          Travel
# ye                People & Society
# za              Books & Literature
# zm              Sensitive Subjects
# zw                           Games
# Name: category, dtype: object

# %%
print("# 5. Country with multiple sites/subdomains: ", country_with_most_ws_sd_df)
# Out:
# # 5. Country with multiple sites/subdomains:  ru

# %%
output_dir = 'output_arrow'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

table = pa.Table.from_pandas(df)

pq.write_to_dataset(
    table,
    root_path=output_dir,
    partition_cols=['category']
)
